# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib notebook

import datetime as datetime
import pandas as pd
import numpy as np
 
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ## Carga de datos y visualización de cada csv

# %%
educacion = pd.read_csv('fiuba_1_postulantes_educacion.csv',sep=',', error_bad_lines=False, encoding='ISO-8859-1')
educacion.tail()
# Out:
#        idpostulante              nombre      estado
# 298226      GNZqARp  Terciario/TÃ©cnico  Abandonado
# 298227      ow2p8vk       Universitario  Abandonado
# 298228      6rPEvwv       Universitario  Abandonado
# 298229      vVja45X       Universitario  Abandonado
# 298230      1QPMbX3       Universitario  Abandonado

# %%
genero_y_edad = pd.read_csv('fiuba_2_postulantes_genero_y_edad.csv', sep=',', error_bad_lines=False, encoding='ISO-8859-1')
genero_y_edad.tail()
# Out:
#        idpostulante fechanacimiento        sexo
# 200883      1QPMbX3      1988-01-07        MASC
# 200884      0zPa0eq      1998-05-09         FEM
# 200885      2zP6Jd0      1997-03-06         FEM
# 200886      8MPoxDW      1997-07-07        MASC
# 200887      2zP6J9V             NaN  NO_DECLARA

# %%
visitas = pd.read_csv('fiuba_3_vistas.csv', sep=',', error_bad_lines=False, encoding='ISO-8859-1')
visitas.tail()
# Out:
#            idAviso                     timestamp idpostulante
# 961892  1112366944  2018-02-28T23:59:08.772-0500      MVPj3AK
# 961893  1001442844  2018-02-28T23:59:37.000-0500      VNrYP6m
# 961894  1112362644  2018-02-28T23:59:46.181-0500      owzLD43
# 961895  1112305277  2018-02-28T23:59:52.754-0500      A3DraY1
# 961896  1112345900  2018-02-28T23:59:55.409-0500      ekmNzBW

# %%
postulaciones = pd.read_csv('fiuba_4_postulaciones.csv', sep=',', error_bad_lines=False, encoding='ISO-8859-1')
postulaciones.tail()
# Out:
#             idaviso idpostulante     fechapostulacion
# 3401618  1111753681      0zPa0eq  2018-02-28 23:54:44
# 3401619  1112369306      2zP6Jd0  2018-02-28 23:57:43
# 3401620  1112308651      8MPoxDW  2018-02-28 23:52:13
# 3401621  1112341128      8MPoxDW  2018-02-28 23:59:06
# 3401622  1112369825      2zP6J9V  2018-02-28 23:56:10

# %%
avisos_online = pd.read_csv('fiuba_5_avisos_online.csv', sep=',', error_bad_lines=False, encoding='ISO-8859-1')
avisos_online.tail()
# Out:
#          idaviso
# 5023  1112387966
# 5024  1112383275
# 5025  1112388199
# 5026  1112388376
# 5027  1112387833

# %%
avisos_detalle = pd.read_csv('fiuba_6_avisos_detalle.csv', sep=',', error_bad_lines=False, encoding='ISO-8859-1')
avisos_detalle.tail()
# Out:
#           idaviso  idpais                                             titulo  \
# 13529  1112342505       1                      Vendedor de Salon -- UNOMOTOS
# 13530  1112342513       1                OPERADOR DE ENSAYOS NO DESTRUCTIVOS
# 13531  1112342456       1  Back officer Junior de Fondos Comunes de Inver...
# 13532  1112342496       1                           Asistente Administrativo
# 13533  1112342432       1  Ingeniero para coordinaciÃ³n de obras de canal...
#
#                                              descripcion        nombre_zona  \
# 13529  <p>UNOMOTOS Concesionaria lÃ­der en el rubro d...  Gran Buenos Aires
# 13530  <p><strong>RECONOCIDA EMPRESA DE MONTAJES INDU...  Gran Buenos Aires
# 13531  <p>BNP Paribas Investment Partners, importante...  Gran Buenos Aires
# 13532  <p>Somos un joven grupo gastronÃ³mico, que se ...  Gran Buenos Aires
# 13533  <p>Importante empresa de servicios para obras ...  Gran Buenos Aires
#
#       ciudad mapacalle tipo_de_trabajo                          nivel_laboral  \
# 13529    NaN       NaN       Full-time                   Senior / Semi-Senior
# 13530    NaN       NaN       Full-time                   Senior / Semi-Senior
# 13531    NaN       NaN       Full-time                                 Junior
# 13532    NaN       NaN       Full-time  Gerencia / Alta Gerencia / DirecciÃ³n
# 13533    NaN       NaN       Full-time        Jefe / Supervisor / Responsable
#
#                                    nombre_area  \
# 13529                                   Ventas
# 13530  IngenierÃ­a Oficina TÃ©cnica / Proyecto
# 13531                             Contabilidad
# 13532                          AdministraciÃ³n
# 13533                            ConstrucciÃ³n
#
#                                 denominacion_empresa
# 13529                                       UNOMOTOS
# 13530                                Grupo Consultor
# 13531  BNP PARIBAS ARGENTINA INVESTMENT PARTNERS S A
# 13532                             Cerveteca Odin Srl
# 13533                                      CIMA S.A.

# %% [markdown]
# ## Merge entre los archivos educación y género y edad de los postulantes
#
# Unimos los datos de ambos data frame con el fin de colocar todos los datos de los postulantes en un mismo data frame

# %%
postulantes = pd.merge(educacion, genero_y_edad, on='idpostulante', how='outer')
postulantes.tail()
# Out:
#        idpostulante nombre estado fechanacimiento        sexo
# 310362      mzdNo99    NaN    NaN      1999-08-10         FEM
# 310363      Nzr1J34    NaN    NaN             NaN  NO_DECLARA
# 310364      JBrNMNk    NaN    NaN      1997-01-11        MASC
# 310365      2zP6Jd0    NaN    NaN      1997-03-06         FEM
# 310366      2zP6J9V    NaN    NaN             NaN  NO_DECLARA

# %% [markdown]
# ## Merge entre los archivos avisos_online y avisos_detalle
#
# Unimos ambos datos frame con el fin de colocar los datos de todos los avisos en un mismo data frame

# %%
avisos = pd.merge(avisos_online, avisos_detalle, on='idaviso', how='outer')
avisos.tail()
# Out:
#           idaviso  idpais                                             titulo  \
# 13844  1112342204     1.0  Ejecutivo de Ventas - Prov. de Bs. As e Interi...
# 13845  1112341862     1.0  24 Feb - Chief Software Architect ($100K/yr) -...
# 13846  1112341899     1.0  24 Feb - Customer Support Manager ($100K/yr) -...
# 13847  1112341992     1.0  24 Feb - VP of Customer Support ($200K/yr) - O...
# 13848  1112342193     1.0                        Supervisor de Mantenimiento
#
#                                              descripcion        nombre_zona  \
# 13844  <p>Editorial Rubinzal Culzoni, lÃ­der en el Ã¡...  Gran Buenos Aires
# 13845  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13846  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13847  <p>Para inscribirse en el torneo debe ingresar...  Gran Buenos Aires
# 13848  <p>Nuestro cliente, un importante PYME dedicad...  Gran Buenos Aires
#
#       ciudad mapacalle tipo_de_trabajo                    nivel_laboral  \
# 13844    NaN       NaN       Full-time             Senior / Semi-Senior
# 13845    NaN       NaN     Teletrabajo  Jefe / Supervisor / Responsable
# 13846    NaN       NaN     Teletrabajo  Jefe / Supervisor / Responsable
# 13847    NaN       NaN     Teletrabajo  Jefe / Supervisor / Responsable
# 13848    NaN       NaN       Full-time  Jefe / Supervisor / Responsable
#
#                  nombre_area denominacion_empresa
# 13844                 Ventas   Rubinzal Editorial
# 13845  Tecnologia / Sistemas            CrossOver
# 13846       Soporte TÃ©cnico            CrossOver
# 13847   AtenciÃ³n al Cliente            CrossOver
# 13848          Mantenimiento        VF CONSULTING

# %% [markdown]
# ## Analizando el set de datos de avisos
#
# Se analiza este set de datos puntualmente, ya que queremos filtrar datos que pertenezcan a CABA y GBA.
# En particular haremos enfazis en las columnas, idpais, nombre_zona, ciudad y mapacalle

# %%
avisos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13849 entries, 0 to 13848
# Data columns (total 11 columns):
# idaviso                 13849 non-null int64
# idpais                  13534 non-null float64
# titulo                  13534 non-null object
# descripcion             13534 non-null object
# nombre_zona             13534 non-null object
# ciudad                  47 non-null object
# mapacalle               872 non-null object
# tipo_de_trabajo         13534 non-null object
# nivel_laboral           13534 non-null object
# nombre_area             13534 non-null object
# denominacion_empresa    13529 non-null object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 1.3+ MB

# %% [markdown]
# ## CHIC@S
# ### 1) considero que no hay que tomar la col ciudad y mapacalle, ya que existe 13802 null y 12977 null, son datos

# %%
avisos.isnull().sum()
# Out:
# idaviso                     0
# idpais                    315
# titulo                    315
# descripcion               315
# nombre_zona               315
# ciudad                  13802
# mapacalle               12977
# tipo_de_trabajo           315
# nivel_laboral             315
# nombre_area               315
# denominacion_empresa      320
# dtype: int64

# %% [markdown]
# ## CHIC@S
# ### 2) Considero en limpiar el dato Bs As (fuera de GBA)

# %%
#Verificamos que las zonas sean solo de Cap Fed y GBA
avisos.nombre_zona.value_counts()
# Out:
# Gran Buenos Aires              12654
# Capital Federal                  876
# GBA Oeste                          2
# Buenos Aires (fuera de GBA)        2
# Name: nombre_zona, dtype: int64

# %% [markdown]
# ## CHIC@S
# ### 3) Analizando que datos diferentes a null existe en la col ciudad, se puede ver que hay datos mal cargados, esto tb es otro motivo más (a mi parecer) de no considerar para nuestro analisis esta columna

# %%
#Verificamos que las ciudades pertenezcan sólo a CABA y GBA
avisos.ciudad.value_counts()
# Out:
# Buenos Aires                 14
# Argentina                    13
# CABA                          3
# Capital Federal               2
# San Isidro                    2
# Vicente Lopez                 1
# Mendoza                       1
# Santa Rosa                    1
# La Plata                      1
# Tortuguitas                   1
# Parque Patricios              1
# Barracas                      1
# Microcentro                   1
# paternal                      1
# RepÃºblica Argentina          1
# Buenos Aires Province         1
# caba                          1
# ZÃ¡rate, Campana, Escobar     1
# Name: ciudad, dtype: int64

# %%
avisos.mapacalle.value_counts()
# Out:
# SARMIENTO 1937                              43
# Microcentro                                 30
# Buenos Aires                                24
# Palermo                                     23
# Barracas                                    18
# Puerto Madero                               15
# Belgrano                                    14
# Reconquista 865                             13
# retiro                                      12
# Parque Patricios                            10
# Recoleta                                    10
# saavedra                                     8
# nuÃ±ez                                       8
# Peron 955                                    7
# San Telmo                                    6
# Monserrat                                    6
# 25 de Mayo 457 7Âº piso                      6
# Mataderos                                    6
# Pasaje Aguado 628                            6
# calle 7 nÂº1565 e/64 y 65                    5
# Av. Libertador 6810 4Âº A                    5
# AmenÃ¡bar 1074                               5
# Villa Soldati                                5
# Florencio varela 3215                        4
# Lavalle 1790                                 4
# Peru 159                                     4
# Nicasio OroÃ±o 1420                          4
# San Isidro                                   4
# Buenos Aires 1480                            4
# MÃ©xico 2051                                 4
#                                             ..
# Avenida congreso 2526                        1
# Av. Marquez 1215                             1
# Au Panamericana, El Talar, Buenos Aires      1
# MIGUELETES 1231                              1
# mercedes                                     1
# Ruta Nacional 188 Km 800                     1
# austria 2100                                 1
# Bolivar 200 Ramos Mejia                      1
# Ciudad de la paz 353                         1
# Ruperto Mazza 339                            1
# Nicasio OroÃ±o 2424                          1
# Ãlvarez Thomas 1130, Villa Rosa             1
# Quilmes Oeste                                1
# BARRIO BELGRANO                              1
# Esmeralda 605 piso 1                         1
# SARMIENTO 520                                1
# De los Calabreses 4204                       1
# Paraguay 2041 4 B                            1
# calle 95 1249 Villa Lynch                    1
# Av Independencia 3976                        1
# Adolfo Alsina 180                            1
# AV.CORRIENTES 4651                           1
# Avenida Mariano Castex, Canning, Ezeiza.     1
# Tucuman 825                                  1
# Avenida ColÃ³n 778                           1
# L. N. Alem 530 7Â°                           1
# Los Patos 2948                               1
# Avenida Cordoba 333 Piso 7                   1
# Bernardo de Irigoyen 722                     1
# Teniente General PerÃ³n 1628, 6to Piso       1
# Name: mapacalle, Length: 487, dtype: int64

# %% [markdown]
# ## Limpieza del set de datos de avisos
# Se limpia todos los nans que pueda aparecer en la columna nombre_zona, la justificación es los ptos 1) y 2) que se recalco

# %%
avisos.dropna(subset=['nombre_zona'],inplace=True)

# %% [markdown]
# ## Filtración de datos por CABA y GBA

# %%
avisosGran_Bs_As=avisos.loc[avisos.nombre_zona.str.contains('Gran Buenos Aires'),:]
avisosGBA_Oeste =avisos.loc[avisos.nombre_zona.str.contains('GBA Oeste'),:]

avisosGBA=pd.concat([avisosGBA_Oeste,avisosGran_Bs_As])

# %%
avisosCABA=avisos.loc[avisos.nombre_zona.str.contains('Capital Federal'),:]

avisosCABA_GBA=pd.concat([avisosCABA,avisosGBA])

# %% [markdown]
# ## Eliminación de columnas
# Se limpia las columnas por los siguientes motivos:
#
#   * idpais: existe 315 datos nullos y representa menos del 2,5% .Los datos diferentes a nulos, tienen un unico id
#
#   * ciudad: existe 13802 datos nulos y aquellos datos diferente a nulos, son datos mal cargados
#
#   * mapacalle: existe 12977 datos nulos (representa el 93,7% del total de los datos),no es relevante para nuestro      analisis

# %%
avisosCABA_GBA.drop(["idpais", "ciudad", "mapacalle"],axis=1,inplace=True)

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Preguntas Gonzalo (9,10,11,12)

# %% [markdown]
# ### A partir de los dataFrames avisosCABA_GBA, postulantes y postulaciones obtengo un unico dataFrame con el cual vamos a trabajar de ahora en adelante

# %% [markdown]
# #### Primero mergeamos los dataFrames postulaciones y postulantes por el campo "idpostulante"

# %%
data = pd.merge(postulantes, postulaciones, on='idpostulante', how='outer')

data.head()
# Out:
#   idpostulante    nombre    estado fechanacimiento  sexo     idaviso  \
# 0         NdJl  Posgrado  En Curso      1969-05-09  MASC  1112261212
# 1         NdJl  Posgrado  En Curso      1969-05-09  MASC  1112273308
# 2         NdJl  Posgrado  En Curso      1969-05-09  MASC  1112281548
# 3         NdJl  Posgrado  En Curso      1969-05-09  MASC  1112260409
# 4         NdJl  Posgrado  En Curso      1969-05-09  MASC  1112293547
#
#       fechapostulacion
# 0  2018-01-16 08:50:30
# 1  2018-01-23 07:53:47
# 2  2018-01-24 05:10:12
# 3  2018-01-24 05:17:29
# 4  2018-01-29 15:41:43

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5630562 entries, 0 to 5630561
# Data columns (total 7 columns):
# idpostulante        object
# nombre              object
# estado              object
# fechanacimiento     object
# sexo                object
# idaviso             int64
# fechapostulacion    object
# dtypes: int64(1), object(6)
# memory usage: 343.7+ MB

# %% [markdown]
# #### Y ahora mergeamos el dataFrame anterior con avisosCABA_GBA por el campo "idaviso"s

# %%
dataFrame = pd.merge(data, avisosCABA_GBA, on='idaviso', how='outer')

dataFrame.head()
# Out:
#   idpostulante              nombre    estado fechanacimiento  sexo  \
# 0         NdJl            Posgrado  En Curso      1969-05-09  MASC
# 1         NdJl       Universitario  Graduado      1969-05-09  MASC
# 2       EppJmb       Universitario  En Curso      1960-06-20  MASC
# 3       EppJmb       Universitario  Graduado      1960-06-20  MASC
# 4       8Zr1GD  Terciario/TÃ©cnico  En Curso      1975-06-29  MASC
#
#       idaviso     fechapostulacion  \
# 0  1112261212  2018-01-16 08:50:30
# 1  1112261212  2018-01-16 08:50:30
# 2  1112261212  2018-01-16 18:51:39
# 3  1112261212  2018-01-16 18:51:39
# 4  1112261212  2018-01-17 10:08:22
#
#                                               titulo  \
# 0  JÃ³venes Profesionales - Responsable Administr...
# 1  JÃ³venes Profesionales - Responsable Administr...
# 2  JÃ³venes Profesionales - Responsable Administr...
# 3  JÃ³venes Profesionales - Responsable Administr...
# 4  JÃ³venes Profesionales - Responsable Administr...
#
#                                          descripcion        nombre_zona  \
# 0  <p>Nos encontramos en la bÃºsqueda de un<stron...  Gran Buenos Aires
# 1  <p>Nos encontramos en la bÃºsqueda de un<stron...  Gran Buenos Aires
# 2  <p>Nos encontramos en la bÃºsqueda de un<stron...  Gran Buenos Aires
# 3  <p>Nos encontramos en la bÃºsqueda de un<stron...  Gran Buenos Aires
# 4  <p>Nos encontramos en la bÃºsqueda de un<stron...  Gran Buenos Aires
#
#   tipo_de_trabajo                    nivel_laboral      nombre_area  \
# 0       Full-time  Jefe / Supervisor / Responsable  AdministraciÃ³n
# 1       Full-time  Jefe / Supervisor / Responsable  AdministraciÃ³n
# 2       Full-time  Jefe / Supervisor / Responsable  AdministraciÃ³n
# 3       Full-time  Jefe / Supervisor / Responsable  AdministraciÃ³n
# 4       Full-time  Jefe / Supervisor / Responsable  AdministraciÃ³n
#
#    denominacion_empresa
# 0  EDUCADO EN ARGENTINA
# 1  EDUCADO EN ARGENTINA
# 2  EDUCADO EN ARGENTINA
# 3  EDUCADO EN ARGENTINA
# 4  EDUCADO EN ARGENTINA

# %% [markdown]
# #### A partir de ahora vamos a trabajar con este dataFrame, el cual contiene la informacion de los anteriores
#
# ### Verificamos sus tipos

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5632778 entries, 0 to 5632777
# Data columns (total 14 columns):
# idpostulante            object
# nombre                  object
# estado                  object
# fechanacimiento         object
# sexo                    object
# idaviso                 int64
# fechapostulacion        object
# titulo                  object
# descripcion             object
# nombre_zona             object
# tipo_de_trabajo         object
# nivel_laboral           object
# nombre_area             object
# denominacion_empresa    object
# dtypes: int64(1), object(13)
# memory usage: 644.6+ MB

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Agrupamos todos los avisos que corresponden al mismo area y vemos cuales son las que cuentan con mayor cantidad de publicaciones.

# %%
dataFrame.groupby('nombre_area')['idaviso'].count().sort_values(ascending = False).head()
# Out:
# nombre_area
# Ventas                  656472
# AdministraciÃ³n         520098
# Comercial               370672
# ProducciÃ³n             367181
# AtenciÃ³n al Cliente    331374
# Name: idaviso, dtype: int64

# %% [markdown]
# ### Visualizamos los resultados con un grafico de  barras

# %%
dataFrame.groupby('nombre_area')['idaviso'].agg('count').sort_values(ascending = False)[0:5].plot(kind='bar', rot=90, figsize=(12,8));

plt.title('Areas con mayor cantidad de publicaciones', fontsize=20);
plt.xlabel('Area', fontsize=16);
plt.ylabel('Cantidad de publicaciones', fontsize=16);

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Nos interesaria ver la cantidad de publicaciones que tenemos segun la disponibilidad horaria de los postulantes
#
# #### Para ellos agrupamos por la columna "tipo_de_trabajo", y luego contamos la cantidad de avisos que hay de cada tipo (Full-time, Part-time y otros)

# %%
dataFrame.groupby('tipo_de_trabajo')['idaviso'].count().sort_values(ascending  = False).head()
# Out:
# tipo_de_trabajo
# Full-time     4363569
# Part-time      662800
# Pasantia        27988
# Por Horas       17446
# Temporario      15205
# Name: idaviso, dtype: int64

# %% [markdown]
# #### Eliminamos las que tienen el campo "tipo_de_trabajo" nulo

# %%
disponibilidades_horarias = dataFrame

disponibilidades_horarias.dropna(subset=['tipo_de_trabajo'],inplace=True)

full_time = disponibilidades_horarias.loc[disponibilidades_horarias.tipo_de_trabajo.str.contains('Full-time'),:]

part_time = disponibilidades_horarias.loc[disponibilidades_horarias.tipo_de_trabajo.str.contains('Part-time'),:]

otros = disponibilidades_horarias.loc[~(disponibilidades_horarias.tipo_de_trabajo.str.contains('Full-time|Part-time')),:]

sizes = [len(full_time), len(part_time), len(otros)]
nombres = ['Full-time', 'Part-time', 'Otros']

plt.figure(figsize=(6, 6))
plt.title('Porcentaje de publicaciones segun la disponibilidad horaria', fontsize=12)
plt.pie(sizes, labels=nombres, autopct='%1.1f%%', startangle=20, colors=['orange','green','blue'])
plt.show()

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### ¿Cuales son los avisos a las que mas personas se postulan?
# #### Agrupamos por el titulo del aviso, su id y la denominacion de empresa

# %%
dataFrame.groupby(['titulo','idaviso','denominacion_empresa'])['idpostulante'].count().sort_values(ascending = False).head()
# Out:
# titulo                                         idaviso     denominacion_empresa
# Representante de Atencion al Cliente/ Banco    1112094756  RANDSTAD                  15935
# Asesores de AtenciÃ³n al PÃºblico - Part time  1112345900  Universidad de Palermo    15171
# Cajero/a - Part Time                           1112334791  Farmacity                 15115
# Cajero/a-Repositor/a (Capital Federal)         1112033906  Farmacity                 14987
# Cajero/a - Part Time                           1112204682  Farmacity                 14160
# Name: idpostulante, dtype: int64

# %% [markdown]
# #### Viendo los resultados, podriamos decir que hay avisos que estan duplicados. O sea que la empresa publico en una o mas ocasiones la misma busqueda laboral. Entonces podriamos agrupar simplemente todas los avisos que tengan el mismo titulo y que pertenezcan a la misma empresa (descartanto el idaviso)

# %%
dataFrame.groupby(['titulo','denominacion_empresa'])['idpostulante'].count().sort_values(ascending = False).head()
# Out:
# titulo                                         denominacion_empresa
# Cajero/a - Part Time                           Farmacity                 29275
# Cajero/a-Repositor/a (Capital Federal)         Farmacity                 25184
# Representante de Atencion al Cliente/ Banco    RANDSTAD                  15935
# Asesor/a de Belleza - Part Time                Farmacity                 15879
# Asesores de AtenciÃ³n al PÃºblico - Part time  Universidad de Palermo    15171
# Name: idpostulante, dtype: int64

# %% [markdown]
# #### Por lo cual, ahora los resultados cambian. Siendo la busqueda de Cajero/a - Part Time de Farmacity la que mas postulaciones tiene.

# %% [markdown]
# ### Visualizamos los resultados

# %%
dataFrame.groupby(['titulo','denominacion_empresa'])['idpostulante'].count().sort_values(ascending = False)[1:10].plot(kind='bar',rot = 90,figsize=(10,4),color='blue',fontsize=12)

plt.title('Avisos con mayor cantidad de postulaciones', fontsize=16);
plt.xlabel('Titulo/Empresa', fontsize=16);
plt.ylabel('Cantidad de postulantes', fontsize=16);

# %% [markdown]
# #### Y ahora analizamos el aviso que esta en primera posicion

# %%
cajeroFarmacity = dataFrame
cajeroFarmacity.dropna(subset=['titulo'],inplace=True)
cajeroFarmacity = cajeroFarmacity.loc[cajeroFarmacity.titulo.str.contains('Cajero/a - Part Time'),:]

cajeroFarmacity['tipo_de_trabajo'].describe()
# Out:
# count         29302
# unique            1
# top       Full-time
# freq          29302
# Name: tipo_de_trabajo, dtype: object

# %% [markdown]
# #### Aunque el titulo del anuncio diga que la busqueda es para Part-Time, aca se puede ver que en realidad se trata para disponibilidad Full-Time

# %% [markdown]
# #### Nos centramos en el nivel educativo de los postulantes

# %%
cajeroFarmacity.groupby(['nombre','estado'])['idpostulante'].count().sort_values(ascending = False).head(10)
# Out:
# nombre              estado
# Secundario          Graduado      13623
# Universitario       En Curso       4801
# Otro                Graduado       2053
# Terciario/TÃ©cnico  En Curso       1983
#                     Graduado       1923
# Universitario       Abandonado     1217
#                     Graduado        930
# Otro                En Curso        585
# Terciario/TÃ©cnico  Abandonado      581
# Secundario          En Curso        450
# Name: idpostulante, dtype: int64

# %% [markdown]
# #### La gran mayoria se tratan de personas con estudios secundarios graduado. Seguido de otros con estudios universitarios en curso y mas atras graduados en otras cosas.

# %% [markdown]
# #### Seria interesante saber cual es el rango de edad de estas personas. Para ello utilizamos la calumna "fechanaciemto" de la cual optenemos el año de nacimiento de cada postulante

# %%
import calendar
import warnings
warnings.filterwarnings('ignore')

#Convertimos la fecha fechanaciento en datetime y agregamos el campo año
cajeroFarmacity['fechanacimiento'] = pd.to_datetime(cajeroFarmacity['fechanacimiento'])
cajeroFarmacity['anio'] = cajeroFarmacity['fechanacimiento'].map(lambda x: x.year)
cajeroFarmacity.dropna(subset= ['anio'], inplace=True)
cajeroFarmacity['anio'] = cajeroFarmacity['anio'].apply(lambda x: int(x))

def rango(x):
    if (x[14]>2000):
        return ("Menor a 18")    
    elif (x[14]<=2000) & (x[14]>=1997):  
        return ("18 a 21")    
    elif (x[14]<=1996) & (x[14]>=1993):
        return ("22 a 25")
    elif (x[14]<=1992) & (x[14]>=1988):
        return ("26 a 30")
    elif (x[14]<1988):
        return ("Mayor a 30")
    
cajeroFarmacity['rango_de_edad'] = cajeroFarmacity.apply(rango,axis=1)

cajeroFarmacity.groupby('rango_de_edad')['idpostulante'].count().sort_values(ascending = False).plot(kind='bar',rot = 90,figsize=(10,4),color='orange',fontsize=12)

plt.title('Rango de edad de las personas postuladas', fontsize=16);
plt.xlabel('Rango', fontsize=16);
plt.ylabel('Cantidad de postulantes', fontsize=16);

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Area con postulantes con nivel educativo mas alto

# %% [markdown]
# #### Primero vemos cuales son los niveles educativos que existen

# %%
dataFrame.groupby('nombre')['idpostulante'].count().sort_values(ascending = False).head(10)
# Out:
# nombre
# Secundario            1854451
# Universitario         1747126
# Terciario/TÃ©cnico     786795
# Otro                   460616
# Posgrado               106742
# Master                  53185
# Doctorado                3257
# Name: idpostulante, dtype: int64

# %% [markdown]
# #### Vemos que encabeza la lista los postulantes con nivel secundario (Ya sea en curso o terminado). Y luego de la lista podemos decir que el doctorado es el grado mas alto que se puede tener. Entonces vamos enfocarnos en este, para ver a cuales areas son las que mas se postulan

# %%
doctorado = dataFrame.loc[(dataFrame.nombre.str.contains('Doctorado') & dataFrame.estado.str.contains('Graduado')),:]

doctorado.groupby('nombre_area')['idpostulante'].count().sort_values(ascending = False)[1:10].plot(kind='bar',rot = 90,figsize=(14,4),color='red',fontsize=12)

plt.title('Areas con mayor cantidad de postulantes doctorados', fontsize=20);
plt.xlabel('Area', fontsize=16);
plt.ylabel('Cantidad de postulantes doctorados', fontsize=16);

# %% [markdown]
# # -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Preguntas de OMAR

# %% [markdown]
#  # Sexo con mayor cantidad de postulaciones EN 2108

# %%
genero_y_edad2=genero_y_edad

# %%
genero_y_edad2=genero_y_edad2.groupby('sexo')['idpostulante'].agg(['count'])

# %%
genero_y_edad2
# Out:
#              count
# sexo
# FEM         101981
# MASC         94339
# NO_DECLARA    4568

# %%
ax = genero_y_edad2.plot(kind = "bar",\
                            color =["darkgreen","seagreen","limegreen","lightgreen"] ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
ax.set_ylabel("sexo", fontsize=20)
ax.set_title('estado', fontsize = 20)
ax.set_xlabel("")
# Out:
# Text(0.5,0,'')

# %% [markdown]
# #  Sexo con mayor cantidad de postulados EN 2108

# %%
postulantes_sexo=pd.merge( postulaciones,genero_y_edad,on='idpostulante' , how='inner')
postulantes_sexo.tail()
# Out:
#             idaviso idpostulante     fechapostulacion fechanacimiento  \
# 3401618  1111753681      0zPa0eq  2018-02-28 23:54:44      1998-05-09
# 3401619  1112369306      2zP6Jd0  2018-02-28 23:57:43      1997-03-06
# 3401620  1112308651      8MPoxDW  2018-02-28 23:52:13      1997-07-07
# 3401621  1112341128      8MPoxDW  2018-02-28 23:59:06      1997-07-07
# 3401622  1112369825      2zP6J9V  2018-02-28 23:56:10             NaN
#
#                sexo
# 3401618         FEM
# 3401619         FEM
# 3401620        MASC
# 3401621        MASC
# 3401622  NO_DECLARA

# %%
postulantes_sexo=postulantes_sexo.tail(20)

# %%
postulantes_sexo.groupby('sexo')['idpostulante'].agg(['count'])
# Out:
#             count
# sexo
# FEM             3
# MASC           16
# NO_DECLARA      1

# %%
postulantes_sexo=postulantes_sexo.groupby('sexo')['idpostulante'].agg(['count'])

# %%
postu =postulantes_sexo.plot(kind = "bar",\
                            color =["darkgreen","seagreen","limegreen","lightgreen"] ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
postu.set_ylabel("sexo", fontsize=20)
postu.set_title('estado', fontsize = 20)
postu.set_xlabel("")
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # Sexo con mayor cantidad de visitas

# %%
sexo_visitas=pd.merge( visitas,genero_y_edad,on='idpostulante' , how='inner')
sexo_visitas=sexo_visitas.tail(20)

# %%
sexo_sitas=sexo_visitas.groupby('sexo')['idpostulante'].agg(['count']).plot(kind = "bar",\
                            color =["darkgreen","seagreen","limegreen","lightgreen"] ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
sexo_sitas.set_ylabel("sexo", fontsize=20)
sexo_sitas.set_title('estado', fontsize = 20)
sexo_sitas.set_xlabel("")
# Out:
# Text(0.5,0,'')

# %% [markdown]
#  # Nivel de estudio (ya sea en curso o terminado) de las personas que estan postulados .

# %%
educacion2=educacion

# %%
educacion2=educacion2.groupby('nombre')['idpostulante'].agg(['count']).head().sort_values(by='count',ascending=True)

# %%
educacion2
# Out:
#              count
# nombre
# Doctorado      214
# Master        3598
# Posgrado      7387
# Otro         24748
# Secundario  110256

# %%
educacion2=educacion2
my_colors = [(x/10.0, x/20.0, 0.30) for x in range(len(educacion2))] # <-- Quick gradient example along the Red/Green dimensions.
ax =educacion2.plot(kind = "barh",\
                            color = my_colors ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
ax.set_xlabel('Cantidad de postulantes', fontsize=20);
ax.set_title("Nivel de Estudio", fontsize=20)
ax.set_ylabel(" ")
# Out:
# Text(0,0.5,' ')

# %% [markdown]
#  # Nivel de estudio (ya sea en curso o terminado) de las personas que ya estan postulados

# %%
postulantes_nivelestudio=pd.merge( postulaciones,educacion,on='idpostulante' , how='inner')
postulantes_nivelestudio=postulantes_nivelestudio.tail()

# %%
postulantes_nivelestudio=postulantes_nivelestudio.groupby('nombre')['idpostulante'].agg(['count']).head()

# %%
postulantes_nivelestudio=postulantes_nivelestudio
my_colors = [(x/10.0, x/20.0, 0.30) for x in range(len(postulantes_nivelestudio))] # <-- Quick gradient example along the Red/Green dimensions.
ax =postulantes_nivelestudio.plot(kind = "barh",\
                            color = my_colors ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
ax.set_xlabel('Cantidad de postulantes', fontsize=20);
ax.set_title("Nivel de Estudio", fontsize=20)
ax.set_ylabel(" ")
# Out:
# Text(0,0.5,' ')

# %% [markdown]
# # Y el tipo de trabajo al que mas  se postularon

# %%
postulantes_trabajo=pd.merge( postulaciones,avisos_detalle,on='idaviso' , how='inner')
postulantes_trabajo.tail(10)
# Out:
#             idaviso idpostulante     fechapostulacion  idpais  \
# 3074196  1112358649      W9A98JR  2018-02-24 07:46:02       1
# 3074197  1112207996      ZDl1Y25  2018-01-18 15:04:58       1
# 3074198  1112215478      5mPLovN  2018-01-15 11:49:08       1
# 3074199  1112206214      Bm543E2  2018-01-16 13:01:52       1
# 3074200  1112204918      EzeGQYo  2018-01-16 09:02:50       1
# 3074201  1112205943      PmGYxxj  2018-01-16 10:57:48       1
# 3074202  1112342094      dYJV5K2  2018-02-25 04:48:24       1
# 3074203  1112206295      xkdOVkx  2018-01-15 09:05:45       1
# 3074204  1111378594      NzrwXm4  2018-01-15 19:54:21       1
# 3074205  1112209328      ow2151r  2018-01-15 09:57:21       1
#
#                                                     titulo  \
# 3074196  Desarrollador FullStack Sr con Java, Mentor pa...
# 3074197                      Ingeniero AgrÃ³nomo Comercial
# 3074198  Laminador de Prfv (plÃ¡stico reforzado con fib...
# 3074199              Analista Junior de RRHH - Resistencia
# 3074200                   Gestor Comercial - Grupo Meditel
# 3074201                                     Ingeniero Vial
# 3074202  Desarrolladores JAVA SOA / JBOSS RED HAT // Zo...
# 3074203                                        Farmacutico
# 3074204  We are looking for a Actionscript Developer to...
# 3074205         Operarios con secundario tÃ©cnico Z/LanÃºs
#
#                                                descripcion        nombre_zona  \
# 3074196  Position: Web and Mobile Development Senior me...  Gran Buenos Aires
# 3074197  <p>Nos encontramos en la bÃºsqueda de un Ingen...  Gran Buenos Aires
# 3074198  <p>Imporante empresa en zona norte incorpora, ...  Gran Buenos Aires
# 3074199  <p>Nos encontramos en la bÃºsqueda de un ANALI...  Gran Buenos Aires
# 3074200  <p style="">Grupo Meditel busca incorporar par...  Gran Buenos Aires
# 3074201  <p>Importante empresa Constructora busca Ingen...  Gran Buenos Aires
# 3074202  <p><strong>SOLUTIX</strong>Â estÃ¡ en la bÃºsq...  Gran Buenos Aires
# 3074203  <p>HELIOS SALUDÂ se encuentra en laÂ bÃºsqueda...    Capital Federal
# 3074204  <div>Globant's Gaming Studio works with the to...  Gran Buenos Aires
# 3074205  <p>Estamos en la bÃºsqueda de operarios con se...  Gran Buenos Aires
#
#         ciudad  mapacalle tipo_de_trabajo         nivel_laboral  \
# 3074196    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074197    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074198    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074199    NaN        NaN       Full-time                Junior
# 3074200    NaN        NaN       Part-time  Senior / Semi-Senior
# 3074201    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074202    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074203    NaN  San Telmo       Full-time  Senior / Semi-Senior
# 3074204    NaN        NaN       Full-time  Senior / Semi-Senior
# 3074205    NaN        NaN       Full-time  Senior / Semi-Senior
#
#                    nombre_area                denominacion_empresa
# 3074196          ProgramaciÃ³n                             MindHub
# 3074197                 Ventas                          SitioLinks
# 3074198            ProducciÃ³n  Pullmen Servicios Empresarios S.A.
# 3074199       Recursos Humanos      Consultora de Recursos Humanos
# 3074200                 Ventas                             MEDITEL
# 3074201          ConstrucciÃ³n        Ezentya Consultora en RR.HH.
# 3074202          ProgramaciÃ³n                       SOLUTIX S.A.
# 3074203          FarmacÃ©utica                        HELIOS SALUD
# 3074204  Tecnologia / Sistemas                             Globant
# 3074205            ProducciÃ³n  Pullmen Servicios Empresarios S.A.

# %%
postulantes_trabajo=postulantes_trabajo.tail(10)

# %%
 postulantes_trabajo.groupby('tipo_de_trabajo')['idpostulante'].agg(['count']).head()
# Out:
#                  count
# tipo_de_trabajo
# Full-time            9
# Part-time            1

# %%
postulantes_trabajo=postulantes_trabajo.groupby('tipo_de_trabajo')['idpostulante'].agg(['count']).head() 
my_colors = [(x/10.0, x/20.0, 0.30) for x in range(len(postulantes_trabajo))] # <-- Quick gradient example along the Red/Green dimensions.
ax =postulantes_trabajo.plot(kind = "barh",\
                            color = my_colors ,\
                            fontsize=20,figsize = (15,8), rot = 45, legend = False)
ax.set_xlabel('cantidad', fontsize=20);
ax.set_title("Tipo de Trabajo al que se postularon", fontsize=20)
ax.set_ylabel(" ")
# Out:
# Text(0,0.5,' ')

# %%
avisos_detalle2.plot.scatter('idaviso','idpais',alpha=0.25,figsize=(12,8));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-6b5b452e046d> in <module>()
# ----> 1 avisos_detalle2.plot.scatter('idaviso','idpais',alpha=0.25,figsize=(12,8));
#
# NameError: name 'avisos_detalle2' is not defined
