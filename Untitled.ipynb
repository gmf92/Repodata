# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
postulantesEducacion=pd.read_csv('fiuba_1_postulantes_educacion.csv',low_memory=False)
postulantesGeneroYEdad=pd.read_csv('fiuba_2_postulantes_genero_y_edad.csv',low_memory=False)
vistas=pd.read_csv('fiuba_3_vistas.csv',low_memory=False)
#postulaciones=pd.read_csv('fiuba_4_postulaciones.csv',low_memory=False)
#avisosOnline=pd.read_csv('fiuba_5_avisos_online.csv',low_memory=False)
avisosDetalle=pd.read_csv('fiuba_6_avisos_detalle.csv',low_memory=False)

datosFaltantes = pd.read_csv('fiuba_6_avisos_detalle_missing_nivel_laboral.csv',low_memory=False)

test_final=pd.read_csv('test_final_100k.csv',low_memory=False)

# %%
test_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
# id              100000 non-null int64
# idaviso         100000 non-null int64
# idpostulante    100000 non-null object
# dtypes: int64(2), object(1)
# memory usage: 2.3+ MB

# %%
test_final.describe()
# Out:
#                   id       idaviso
# count  100000.000000  1.000000e+05
# mean    49999.500000  1.105252e+09
# std     28867.657797  8.602712e+07
# min         0.000000  7.392600e+05
# 25%     24999.750000  1.112326e+09
# 50%     49999.500000  1.112439e+09
# 75%     74999.250000  1.112464e+09
# max     99999.000000  1.112515e+09

# %%
test_final.head(20)
# Out:
#     id  idaviso idpostulante
# 0    0   739260       6M9ZQR
# 1    1   739260       6v1xdL
# 2    2   739260       ezRKm9
# 3    3   758580       1Q35ej
# 4    4   758580       EAN4J6
# 5    5   758580       8R6pzR
# 6    6   776420       aZJ2XN
# 7    7   776420       Nmpo3J
# 8    8   776420       eVqWar
# 9    9   820850       6ZBD33
# 10  10   820850       1j4RNj
# 11  11   820850        ZOwE8
# 12  12   820850       NG4BaD
# 13  13   914880       6q6eNl
# 14  14   914880       8E8pWj
# 15  15   914880       eVqbDr
# 16  16  1112360       6kRZ44
# 17  17  1112360       8XGB3D
# 18  18  1112360       5qVB9X
# 19  19  1112360       Z6zxXZ

# %%
postulantesGeneroYEdad.info()
#fechanacimiento* (convertir en un numero), sexo
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 281385 entries, 0 to 281384
# Data columns (total 3 columns):
# idpostulante       281385 non-null object
# fechanacimiento    268482 non-null object
# sexo               281385 non-null object
# dtypes: object(3)
# memory usage: 6.4+ MB

# %%
#Hay una difencia de datos entre la columna fechanacimiento y sexo
#Entonces para elloslos completamos con la media o el promedio de todos

# %%
postulantesEducacion.info()
#estado, nombre
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397509 entries, 0 to 397508
# Data columns (total 3 columns):
# idpostulante    397509 non-null object
# nombre          397509 non-null object
# estado          397509 non-null object
# dtypes: object(3)
# memory usage: 9.1+ MB

# %%
vistas.info()
#Agregar columna con la cantidad de veces que vio la publicacion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11648230 entries, 0 to 11648229
# Data columns (total 3 columns):
# idAviso         int64
# timestamp       object
# idpostulante    object
# dtypes: int64(1), object(2)
# memory usage: 266.6+ MB

# %%
avisosDetalle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13798 entries, 0 to 13797
# Data columns (total 11 columns):
# idaviso                 13798 non-null int64
# idpais                  13798 non-null int64
# titulo                  13798 non-null object
# descripcion             13798 non-null object
# nombre_zona             13798 non-null object
# ciudad                  86 non-null object
# mapacalle               1019 non-null object
# tipo_de_trabajo         13798 non-null object
# nivel_laboral           13798 non-null object
# nombre_area             13798 non-null object
# denominacion_empresa    13795 non-null object
# dtypes: int64(2), object(9)
# memory usage: 1.2+ MB

# %%
avisosDetalle.head()
#nombre_area, tipo_de_trabajo, nivel_laboral, denominacion_empresa, nombre_zona, titulo
# Out:
#    idaviso  idpais                                       titulo  \
# 0  1573840       1                                  VENDEDORA/O
# 1  1712970       1                        INGENIERO DE PRODUCTO
# 2  1719970       1  ** Diseñadores/as Gráficos Quark Express **
# 3  1720060       1                              Soporte Tecnico
# 4  1720280       1                        ADSCRIPTO DE GERENCIA
#
#                                          descripcion  \
# 0  Nuestra Búsqueda se orienta a la incorporación...
# 1  INGENIERO ELECTRICISTA/ELECTRONICO CON CONOCIM...
# 2  Diseñadores/as Gráficos Quark Express para Rev...
# 3  Estudiante de Sistemas (Lic. en Sistemas de la...
# 4  Importante Organización Académica Empresarial\...
#
#                    nombre_zona  ciudad mapacalle tipo_de_trabajo  \
# 0              Capital Federal  Flores       NaN       Full-time
# 1              Capital Federal     NaN       NaN       Full-time
# ...

# %%
postulantesEducacion.head(20)
# Out:
#    idpostulante             nombre    estado
# 0           YZP             Master  En Curso
# 1          ZjlZ             Master  En Curso
# 2         aEW8J      Universitario  En Curso
# 3         8QGRj      Universitario  En Curso
# 4        eRYl5r      Universitario  En Curso
# 5        1lKNa3      Universitario  En Curso
# 6        NA84GJ      Universitario  En Curso
# 7        a61Yo5      Universitario  En Curso
# 8        ZjdkqZ      Universitario  En Curso
# 9        8wKOpM      Universitario  En Curso
# 10       EDM1x8      Universitario  En Curso
# 11       NA8aX5               Otro  En Curso
# 12       eRYqor      Universitario  En Curso
# 13       6kKXLv      Universitario  En Curso
# 14       8wK4Pl      Universitario  En Curso
# 15       E5bKKJ  Terciario/Técnico  En Curso
# 16       82PYmL      Universitario  En Curso
# 17       EEeGl8      Universitario  En Curso
# 18       82OLmR  Terciario/Técnico  En Curso
# 19       ZroBQ1      Universitario  En Curso

# %%
postulantesGeneroYEdad.head()
# Out:
#   idpostulante fechanacimiento        sexo
# 0          6MM      1985-01-01        MASC
# 1          ZX1             NaN  NO_DECLARA
# 2          YZP      1961-05-01        MASC
# 3          ebE      1952-07-07        MASC
# 4          N1x             NaN  NO_DECLARA

# %%
postulantesEducacion.groupby(['idpostulante', 'nombre', 'estado']).count()
#Agregar funcion para definir cual es el nivel mas alto educativo y darle un valor
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
postulantesGeneroYEdad.groupby('idpostulante').count().sort_values(by=['sexo'],ascending = False)
# Out:
#               fechanacimiento  sexo
# idpostulante
# 0z5JW1r                     1     1
# a110V0                      1     1
# a12mv5                      1     1
# a12j55                      1     1
# a12GN5                      1     1
# a120o9                      1     1
# a11vxE                      1     1
# a11Q85                      1     1
# a10jVW                      1     1
# a18p8E                      1     1
# a10J50                      1     1
# a10GZ0                      1     1
# a10EAE                      1     1
# a0zWD0                      1     1
# a0zR9m                      1     1
# a0zNYN                      1     1
# a12oWD                      1     1
# a132rD                      1     1
# a13DdJ                      1     1
# a13XKE                      1     1
# a13brW                      1     1
# a13vNE                      1     1
# a14Q05                      1     1
# a14Xeq                      1     1
# ...

# %%
#El csv postulantesGeneroYEdad no tiene repetidos
#Concluimos que el archivo postulantesGeneroYEdad no contiene todos los datos de test_final
#Al hacer el merge consideramos por medio del how='left' quedarnos solo con los datos que se encontraban en el dataFrame test_final

# %%
dataFrame = pd.merge(test_final, postulantesGeneroYEdad, on='idpostulante', how='left')

# %%
dataFrame.head(20)
# Out:
#     id  idaviso idpostulante fechanacimiento  sexo
# 0    0   739260       6M9ZQR      1976-03-29   FEM
# 1    1   739260       6v1xdL             NaN   NaN
# 2    2   739260       ezRKm9      1982-02-17   FEM
# 3    3   758580       1Q35ej             NaN   NaN
# 4    4   758580       EAN4J6             NaN   NaN
# 5    5   758580       8R6pzR      1990-05-29  MASC
# 6    6   776420       aZJ2XN      1989-01-23  MASC
# 7    7   776420       Nmpo3J      1964-02-13  MASC
# 8    8   776420       eVqWar             NaN   NaN
# 9    9   820850       6ZBD33      1980-09-18  MASC
# 10  10   820850       1j4RNj             NaN   NaN
# 11  11   820850        ZOwE8      1979-10-22   FEM
# 12  12   820850       NG4BaD      1990-03-18   FEM
# 13  13   914880       6q6eNl      1972-12-12  MASC
# 14  14   914880       8E8pWj             NaN   NaN
# 15  15   914880       eVqbDr      1983-03-25   FEM
# 16  16  1112360       6kRZ44             NaN   NaN
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 5 columns):
# id                 100000 non-null int64
# idaviso            100000 non-null int64
# idpostulante       100000 non-null object
# fechanacimiento    76939 non-null object
# sexo               78728 non-null object
# dtypes: int64(2), object(3)
# memory usage: 4.6+ MB

# %%
cantidad_actual = dataFrame.count()
print cantidad_actual
# Out:
# id                 100000
# idaviso            100000
# idpostulante       100000
# fechanacimiento     76939
# sexo                78728
# dtype: int64

# %%
prueba = dataFrame
prueba.dropna(inplace=True)
cantidad_sinNan = prueba.count()
print cantidad_sinNan
# Out:
# id                 76939
# idaviso            76939
# idpostulante       76939
# fechanacimiento    76939
# sexo               76939
# dtype: int64

# %%
diferencia = cantidad_actual['idpostulante'] - cantidad_sinNan['idpostulante']
print diferencia
# Out:
# 23061

# %%
dataFrame.groupby('idpostulante').count()
# Out:
#               id  idaviso  fechanacimiento  sexo
# idpostulante
# 0zB0LYv        1        1                1     1
# 0zB0v4v        1        1                1     1
# 0zB1369        2        2                2     2
# 0zB35QY        2        2                2     2
# 0zB4Lbd       11       11               11    11
# 0zB5zKd        1        1                1     1
# 0zB6KOM        4        4                4     4
# 0zB8bmE       13       13               13    13
# 0zBAqNM        1        1                1     1
# 0zBDZRq       20       20               20    20
# 0zBDkja        6        6                6     6
# 0zBEL2v        4        4                4     4
# 0zBGR4M       11       11               11    11
# 0zBGo4d       10       10               10    10
# 0zBJ0ar       11       11               11    11
# 0zBJGe1        1        1                1     1
# 0zBKL3Y        1        1                1     1
# 0zBKed1       10       10               10    10
# ...
